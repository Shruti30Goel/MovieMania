# %%
import pandas as pd
import numpy as np
import requests
import bs4 as bs
import urllib.request

# %% [markdown]
# ## Extracting features of 2018 movies from Wikipedia

# %%
link = "https://en.wikipedia.org/wiki/List_of_American_films_of_2018"
df1 = pd.read_html(link, header=0)[2]
df2 = pd.read_html(link, header=0)[3]
df3 = pd.read_html(link, header=0)[4]
df4 = pd.read_html(link, header=0)[5]

# %%
df = df1.append(df2.append(df3.append(df4,ignore_index=True),ignore_index=True),ignore_index=True)

# %%
df
# Out:
#       Opening  Opening.1                       Title  \
# 0     JANUARY          5     Insidious: The Last Key
# 1     JANUARY          5            The Strange Ones
# 2     JANUARY          5                    Stratton
# 3     JANUARY         10               Sweet Country
# 4     JANUARY         12                The Commuter
# ..        ...        ...                         ...
# 267  DECEMBER         25             Holmes & Watson
# 268  DECEMBER         25                        Vice
# 269  DECEMBER         25         On the Basis of Sex
# 270  DECEMBER         25                   Destroyer
# 271  DECEMBER         28  Black Mirror: Bandersnatch
#
#                                     Production company  \
# 0    Universal Pictures / Blumhouse Productions / S...
# 1                               Vertical Entertainment
# 2                                    Momentum Pictures
# 3                                 Samuel Goldwyn Films
# 4        Lionsgate / StudioCanal / The Picture Company
# ..                                                 ...
# 267       Columbia Pictures / Gary Sanchez Productions
# 268          Annapurna Pictures / Plan B Entertainment
# 269                                     Focus Features
# 270                                 Annapurna Pictures
# 271                                            Netflix
#
#                                          Cast and crew  \
# 0    Adam Robitel (director); Leigh Whannell (scree...
# 1    Lauren Wolkstein (director); Christopher Radcl...
# 2    Simon West (director); Duncan Falconer, Warren...
# 3    Warwick Thornton (director); David Tranter, St...
# 4    Jaume Collet-Serra (director); Byron Willinger...
# ..                                                 ...
# 267  Etan Cohen (director/screenplay); Will Ferrell...
# 268  Adam McKay (director/screenplay); Christian Ba...
# 269  Mimi Leder (director); Daniel Stiepleman (scre...
# 270  Karyn Kusama (director); Phil Hay, Matt Manfre...
# 271  David Slade (director); Charlie Brooker (scree...
#
#     .mw-parser-output .tooltip-dotted{border-bottom:1px dotted;cursor:help}Ref.  \
# 0                                                  [2]
# 1                                                  [3]
# 2                                                  [4]
# 3                                                  [5]
# 4                                                  [6]
# ..                                                 ...
# 267                                                NaN
# 268                                                NaN
# 269                                                NaN
# 270                                                NaN
# 271                                                NaN
#
#       Ref.
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
# ..     ...
# 267  [164]
# 268  [137]
# 269  [228]
# 270  [260]
# 271  [261]
#
# [272 rows x 7 columns]

# %%
# !pip install tmdbv3api
# Out:
# Requirement already satisfied: tmdbv3api in c:\users\acer\anaconda3\lib\site-packages (1.7.6)
# Requirement already satisfied: requests in c:\users\acer\anaconda3\lib\site-packages (from tmdbv3api) (2.25.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\acer\anaconda3\lib\site-packages (from requests->tmdbv3api) (2020.12.5)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\acer\anaconda3\lib\site-packages (from requests->tmdbv3api) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\acer\anaconda3\lib\site-packages (from requests->tmdbv3api) (1.26.4)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\acer\anaconda3\lib\site-packages (from requests->tmdbv3api) (2.10)

# %%
from tmdbv3api import TMDb
import json
import requests
tmdb = TMDb()
tmdb.api_key = '76d9e7057c5b2a49d4234f80154f044e'

# %%
from tmdbv3api import Movie
tmdb_movie = Movie()
def get_genre(x):
    genres = []
    result = tmdb_movie.search(x)
    movie_id = result[0].id
    response = requests.get('https://api.themoviedb.org/3/movie/550?api_key=76d9e7057c5b2a49d4234f80154f044e'.format(movie_id,tmdb.api_key))
    data_json = response.json()
    if data_json['genres']:
        genre_str = " " 
        for i in range(0,len(data_json['genres'])):
            genres.append(data_json['genres'][i]['name'])
        return genre_str.join(genres)
    else:
        np.NaN

# %%
df['genres'] = df['Title'].map(lambda x: get_genre(str(x)))

# %%
df
# Out:
#       Opening  Opening.1                       Title  \
# 0     JANUARY          5     Insidious: The Last Key
# 1     JANUARY          5            The Strange Ones
# 2     JANUARY          5                    Stratton
# 3     JANUARY         10               Sweet Country
# 4     JANUARY         12                The Commuter
# ..        ...        ...                         ...
# 267  DECEMBER         25             Holmes & Watson
# 268  DECEMBER         25                        Vice
# 269  DECEMBER         25         On the Basis of Sex
# 270  DECEMBER         25                   Destroyer
# 271  DECEMBER         28  Black Mirror: Bandersnatch
#
#                                     Production company  \
# 0    Universal Pictures / Blumhouse Productions / S...
# 1                               Vertical Entertainment
# 2                                    Momentum Pictures
# 3                                 Samuel Goldwyn Films
# 4        Lionsgate / StudioCanal / The Picture Company
# ..                                                 ...
# 267       Columbia Pictures / Gary Sanchez Productions
# 268          Annapurna Pictures / Plan B Entertainment
# 269                                     Focus Features
# 270                                 Annapurna Pictures
# 271                                            Netflix
#
#                                          Cast and crew  \
# 0    Adam Robitel (director); Leigh Whannell (scree...
# 1    Lauren Wolkstein (director); Christopher Radcl...
# 2    Simon West (director); Duncan Falconer, Warren...
# 3    Warwick Thornton (director); David Tranter, St...
# 4    Jaume Collet-Serra (director); Byron Willinger...
# ..                                                 ...
# 267  Etan Cohen (director/screenplay); Will Ferrell...
# 268  Adam McKay (director/screenplay); Christian Ba...
# 269  Mimi Leder (director); Daniel Stiepleman (scre...
# 270  Karyn Kusama (director); Phil Hay, Matt Manfre...
# 271  David Slade (director); Charlie Brooker (scree...
#
#     .mw-parser-output .tooltip-dotted{border-bottom:1px dotted;cursor:help}Ref.  \
# 0                                                  [2]
# 1                                                  [3]
# 2                                                  [4]
# 3                                                  [5]
# 4                                                  [6]
# ..                                                 ...
# 267                                                NaN
# 268                                                NaN
# 269                                                NaN
# 270                                                NaN
# 271                                                NaN
#
#       Ref. genres
# 0      NaN  Drama
# 1      NaN  Drama
# 2      NaN  Drama
# 3      NaN  Drama
# 4      NaN  Drama
# ..     ...    ...
# 267  [164]  Drama
# 268  [137]  Drama
# 269  [228]  Drama
# 270  [260]  Drama
# 271  [261]  Drama
#
# [272 rows x 8 columns]

# %%
df_2018 = df[['Title','Cast and crew','genres']]

# %%
df_2018
# Out:
#                           Title  \
# 0       Insidious: The Last Key
# 1              The Strange Ones
# 2                      Stratton
# 3                 Sweet Country
# 4                  The Commuter
# ..                          ...
# 267             Holmes & Watson
# 268                        Vice
# 269         On the Basis of Sex
# 270                   Destroyer
# 271  Black Mirror: Bandersnatch
#
#                                          Cast and crew genres
# 0    Adam Robitel (director); Leigh Whannell (scree...  Drama
# 1    Lauren Wolkstein (director); Christopher Radcl...  Drama
# 2    Simon West (director); Duncan Falconer, Warren...  Drama
# 3    Warwick Thornton (director); David Tranter, St...  Drama
# 4    Jaume Collet-Serra (director); Byron Willinger...  Drama
# ..                                                 ...    ...
# 267  Etan Cohen (director/screenplay); Will Ferrell...  Drama
# 268  Adam McKay (director/screenplay); Christian Ba...  Drama
# 269  Mimi Leder (director); Daniel Stiepleman (scre...  Drama
# 270  Karyn Kusama (director); Phil Hay, Matt Manfre...  Drama
# 271  David Slade (director); Charlie Brooker (scree...  Drama
#
# [272 rows x 3 columns]

# %%
def get_director(x):
    if " (director)" in x:
        return x.split(" (director)")[0]
    elif " (directors)" in x:
        return x.split(" (directors)")[0]
    else:
        return x.split(" (director/screenplay)")[0]

# %%
df_2018['director_name'] = df_2018['Cast and crew'].map(lambda x: get_director(x))
# Out:
# <ipython-input-99-4838efec492a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2018['director_name'] = df_2018['Cast and crew'].map(lambda x: get_director(x))

# %%
def get_actor1(x):
    return ((x.split("screenplay); ")[-1]).split(", ")[0])

# %%
df_2018['actor_1_name'] = df_2018['Cast and crew'].map(lambda x: get_actor1(x))
# Out:
# <ipython-input-101-94b1a1569c5d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2018['actor_1_name'] = df_2018['Cast and crew'].map(lambda x: get_actor1(x))

# %%
def get_actor2(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 2:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[1])

# %%
df_2018['actor_2_name'] = df_2018['Cast and crew'].map(lambda x: get_actor2(x))
# Out:
# <ipython-input-103-75f2be6b779a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2018['actor_2_name'] = df_2018['Cast and crew'].map(lambda x: get_actor2(x))

# %%
def get_actor3(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 3:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[2])

# %%
df_2018['actor_3_name'] = df_2018['Cast and crew'].map(lambda x: get_actor3(x))
# Out:
# <ipython-input-105-c6969dc4d5e1>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2018['actor_3_name'] = df_2018['Cast and crew'].map(lambda x: get_actor3(x))

# %%
df_2018
# Out:
#                           Title  \
# 0       Insidious: The Last Key
# 1              The Strange Ones
# 2                      Stratton
# 3                 Sweet Country
# 4                  The Commuter
# ..                          ...
# 267             Holmes & Watson
# 268                        Vice
# 269         On the Basis of Sex
# 270                   Destroyer
# 271  Black Mirror: Bandersnatch
#
#                                          Cast and crew genres  \
# 0    Adam Robitel (director); Leigh Whannell (scree...  Drama
# 1    Lauren Wolkstein (director); Christopher Radcl...  Drama
# 2    Simon West (director); Duncan Falconer, Warren...  Drama
# 3    Warwick Thornton (director); David Tranter, St...  Drama
# 4    Jaume Collet-Serra (director); Byron Willinger...  Drama
# ..                                                 ...    ...
# 267  Etan Cohen (director/screenplay); Will Ferrell...  Drama
# 268  Adam McKay (director/screenplay); Christian Ba...  Drama
# 269  Mimi Leder (director); Daniel Stiepleman (scre...  Drama
# 270  Karyn Kusama (director); Phil Hay, Matt Manfre...  Drama
# 271  David Slade (director); Charlie Brooker (scree...  Drama
#
#           director_name     actor_1_name            actor_2_name  \
# 0          Adam Robitel        Lin Shaye           Angus Sampson
# 1      Lauren Wolkstein    Alex Pettyfer  James Freedson-Jackson
# 2            Simon West   Dominic Cooper          Austin Stowell
# 3      Warwick Thornton      Bryan Brown               Sam Neill
# 4    Jaume Collet-Serra      Liam Neeson            Vera Farmiga
# ..                  ...              ...                     ...
# 267          Etan Cohen     Will Ferrell          John C. Reilly
# 268          Adam McKay   Christian Bale               Amy Adams
# 269          Mimi Leder   Felicity Jones            Armie Hammer
# 270        Karyn Kusama    Nicole Kidman          Sebastian Stan
# 271         David Slade  Fionn Whitehead            Will Poulter
#
#        actor_3_name
# 0    Leigh Whannell
# 1     Emily Althaus
# 2        Gemma Chan
# 3               NaN
# 4    Patrick Wilson
# ..              ...
# 267    Rebecca Hall
# 268    Steve Carell
# 269  Justin Theroux
# 270    Toby Kebbell
# 271   Asim Chaudhry
#
# [272 rows x 7 columns]

# %%
df_2018 = df_2018.rename(columns={'Title':'movie_title'})

# %%
new_df18 = df_2018.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres','movie_title']]

# %%
new_df18
# Out:
#           director_name     actor_1_name            actor_2_name  \
# 0          Adam Robitel        Lin Shaye           Angus Sampson
# 1      Lauren Wolkstein    Alex Pettyfer  James Freedson-Jackson
# 2            Simon West   Dominic Cooper          Austin Stowell
# 3      Warwick Thornton      Bryan Brown               Sam Neill
# 4    Jaume Collet-Serra      Liam Neeson            Vera Farmiga
# ..                  ...              ...                     ...
# 267          Etan Cohen     Will Ferrell          John C. Reilly
# 268          Adam McKay   Christian Bale               Amy Adams
# 269          Mimi Leder   Felicity Jones            Armie Hammer
# 270        Karyn Kusama    Nicole Kidman          Sebastian Stan
# 271         David Slade  Fionn Whitehead            Will Poulter
#
#        actor_3_name genres                 movie_title
# 0    Leigh Whannell  Drama     Insidious: The Last Key
# 1     Emily Althaus  Drama            The Strange Ones
# 2        Gemma Chan  Drama                    Stratton
# 3               NaN  Drama               Sweet Country
# 4    Patrick Wilson  Drama                The Commuter
# ..              ...    ...                         ...
# 267    Rebecca Hall  Drama             Holmes & Watson
# 268    Steve Carell  Drama                        Vice
# 269  Justin Theroux  Drama         On the Basis of Sex
# 270    Toby Kebbell  Drama                   Destroyer
# 271   Asim Chaudhry  Drama  Black Mirror: Bandersnatch
#
# [272 rows x 6 columns]

# %%
new_df18['actor_2_name'] = new_df18['actor_2_name'].replace(np.nan, 'unknown')
new_df18['actor_3_name'] = new_df18['actor_3_name'].replace(np.nan, 'unknown')

# %%
new_df18['movie_title'] = new_df18['movie_title'].str.lower()

# %%
new_df18['comb'] = new_df18['actor_1_name'] + ' ' + new_df18['actor_2_name'] + ' '+ new_df18['actor_3_name'] + ' '+ new_df18['director_name'] +' ' + new_df18['genres']

# %%
new_df18
# Out:
#           director_name     actor_1_name            actor_2_name  \
# 0          Adam Robitel        Lin Shaye           Angus Sampson
# 1      Lauren Wolkstein    Alex Pettyfer  James Freedson-Jackson
# 2            Simon West   Dominic Cooper          Austin Stowell
# 3      Warwick Thornton      Bryan Brown               Sam Neill
# 4    Jaume Collet-Serra      Liam Neeson            Vera Farmiga
# ..                  ...              ...                     ...
# 267          Etan Cohen     Will Ferrell          John C. Reilly
# 268          Adam McKay   Christian Bale               Amy Adams
# 269          Mimi Leder   Felicity Jones            Armie Hammer
# 270        Karyn Kusama    Nicole Kidman          Sebastian Stan
# 271         David Slade  Fionn Whitehead            Will Poulter
#
#        actor_3_name genres                 movie_title  \
# 0    Leigh Whannell  Drama     insidious: the last key
# 1     Emily Althaus  Drama            the strange ones
# 2        Gemma Chan  Drama                    stratton
# 3           unknown  Drama               sweet country
# 4    Patrick Wilson  Drama                the commuter
# ..              ...    ...                         ...
# 267    Rebecca Hall  Drama             holmes & watson
# 268    Steve Carell  Drama                        vice
# 269  Justin Theroux  Drama         on the basis of sex
# 270    Toby Kebbell  Drama                   destroyer
# 271   Asim Chaudhry  Drama  black mirror: bandersnatch
#
#                                                   comb
# 0    Lin Shaye Angus Sampson Leigh Whannell Adam Ro...
# 1    Alex Pettyfer James Freedson-Jackson Emily Alt...
# 2    Dominic Cooper Austin Stowell Gemma Chan Simon...
# 3    Bryan Brown Sam Neill unknown Warwick Thornton...
# 4    Liam Neeson Vera Farmiga Patrick Wilson Jaume ...
# ..                                                 ...
# 267  Will Ferrell John C. Reilly Rebecca Hall Etan ...
# 268  Christian Bale Amy Adams Steve Carell Adam McK...
# 269  Felicity Jones Armie Hammer Justin Theroux Mim...
# 270  Nicole Kidman Sebastian Stan Toby Kebbell Kary...
# 271  Fionn Whitehead Will Poulter Asim Chaudhry Dav...
#
# [272 rows x 7 columns]

# %% [markdown]
# # Extracting features of 2019 movies from Wikipedia

# %%
link = "https://en.wikipedia.org/wiki/List_of_American_films_of_2019"
df1 = pd.read_html(link, header=0)[3]
df2 = pd.read_html(link, header=0)[4]
df3 = pd.read_html(link, header=0)[5]
df4 = pd.read_html(link, header=0)[6]

# %%
df = df1.append(df2.append(df3.append(df4,ignore_index=True),ignore_index=True),ignore_index=True)

# %%
df
# Out:
#       Opening  Opening.1                Title  \
# 0       APRIL        5.0              Shazam!
# 1       APRIL        5.0         Pet Sematary
# 2       APRIL        5.0  The Best of Enemies
# 3       APRIL        5.0            High Life
# 4       APRIL        5.0        Unicorn Store
# ..        ...        ...                  ...
# 188  DECEMBER       25.0    Spies in Disguise
# 189  DECEMBER       25.0         Little Women
# 190  DECEMBER       25.0                 1917
# 191  DECEMBER       25.0           Just Mercy
# 192  DECEMBER       27.0             Clemency
#
#                                     Production company  \
# 0    Warner Bros. Pictures / New Line Cinema / DC F...
# 1                                   Paramount Pictures
# 2                                    STX Entertainment
# 3                    A24 / Arte / ZDF / Canal+ / Ciné+
# 4                                              Netflix
# ..                                                 ...
# 188  20th Century Fox / Blue Sky Studios / Chernin ...
# 189            Columbia Pictures / Regency Enterprises
# 190           Universal Pictures / DreamWorks Pictures
# 191          Warner Bros. Pictures / Participant Media
# 192                                               Neon
#
#                                          Cast and crew   Ref. Unnamed: 0  \
# 0    David F. Sandberg (director); Henry Gayden (sc...   [51]        NaN
# 1    Kevin Kolsch, Dennis Widmyer (directors); Jeff...   [52]        NaN
# 2    Robin Bissell (director/screenplay); Taraji P....   [53]        NaN
# 3    Claire Denis (director/screenplay); Jean-Pol F...   [54]        NaN
# 4    Brie Larson (director); Samantha McIntyre (scr...    NaN        NaN
# ..                                                 ...    ...        ...
# 188  Nick Bruno, Troy Quane (directors); Brad Copel...  [132]        NaN
# 189  Greta Gerwig (director/screenplay); Saoirse Ro...  [221]        NaN
# 190  Sam Mendes (director/screenplay); Krysty Wilso...  [222]        NaN
# 191  Destin Daniel Cretton (director/screenplay), A...  [223]        NaN
# 192  Chinonye Chukwu (director/screenplay); Alfre W...  [224]        NaN
#
#     Wikimedia Commons has media related to Films of the United States, 2019.
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 188                                                NaN
# 189                                                NaN
# 190                                                NaN
# 191                                                NaN
# 192                                                NaN
#
# [193 rows x 8 columns]

# %%
df['genres'] = df['Title'].map(lambda x: get_genre(str(x)))

# %%
df_2019 = df[['Title','Cast and crew','genres']]

# %%
df_2019
# Out:
#                    Title                                      Cast and crew  \
# 0                Shazam!  David F. Sandberg (director); Henry Gayden (sc...
# 1           Pet Sematary  Kevin Kolsch, Dennis Widmyer (directors); Jeff...
# 2    The Best of Enemies  Robin Bissell (director/screenplay); Taraji P....
# 3              High Life  Claire Denis (director/screenplay); Jean-Pol F...
# 4          Unicorn Store  Brie Larson (director); Samantha McIntyre (scr...
# ..                   ...                                                ...
# 188    Spies in Disguise  Nick Bruno, Troy Quane (directors); Brad Copel...
# 189         Little Women  Greta Gerwig (director/screenplay); Saoirse Ro...
# 190                 1917  Sam Mendes (director/screenplay); Krysty Wilso...
# 191           Just Mercy  Destin Daniel Cretton (director/screenplay), A...
# 192             Clemency  Chinonye Chukwu (director/screenplay); Alfre W...
#
#     genres
# 0    Drama
# 1    Drama
# 2    Drama
# 3    Drama
# 4    Drama
# ..     ...
# 188  Drama
# 189  Drama
# 190  Drama
# 191  Drama
# 192  Drama
#
# [193 rows x 3 columns]

# %%
df_2019['director_name'] = df_2019['Cast and crew'].map(lambda x: get_director(str(x)))
# Out:
# <ipython-input-121-a433a4faa834>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2019['director_name'] = df_2019['Cast and crew'].map(lambda x: get_director(str(x)))

# %%
df_2019['actor_1_name'] = df_2019['Cast and crew'].map(lambda x: get_actor1(x))
# Out:
# <ipython-input-122-eee71c5586b8>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2019['actor_1_name'] = df_2019['Cast and crew'].map(lambda x: get_actor1(x))

# %%
df_2019['actor_2_name'] = df_2019['Cast and crew'].map(lambda x: get_actor2(x))
# Out:
# <ipython-input-123-48d0aadc78c0>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2019['actor_2_name'] = df_2019['Cast and crew'].map(lambda x: get_actor2(x))

# %%
df_2019['actor_3_name'] = df_2019['Cast and crew'].map(lambda x: get_actor3(x))
# Out:
# <ipython-input-124-54baf96f0c44>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2019['actor_3_name'] = df_2019['Cast and crew'].map(lambda x: get_actor3(x))

# %%
df_2019 = df_2019.rename(columns={'Title':'movie_title'})

# %%
new_df19 = df_2019.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres','movie_title']]

# %%
new_df19['actor_2_name'] = new_df19['actor_2_name'].replace(np.nan, 'unknown')
new_df19['actor_3_name'] = new_df19['actor_3_name'].replace(np.nan, 'unknown')

# %%
new_df19['movie_title'] = new_df19['movie_title'].str.lower()

# %%
new_df19['comb'] = new_df19['actor_1_name'] + ' ' + new_df19['actor_2_name'] + ' '+ new_df19['actor_3_name'] + ' '+ new_df19['director_name'] +' ' + new_df19['genres']

# %%
new_df19
# Out:
#                     director_name       actor_1_name          actor_2_name  \
# 0               David F. Sandberg       Zachary Levi           Asher Angel
# 1    Kevin Kolsch, Dennis Widmyer       Jason Clarke           Amy Seimetz
# 2                   Robin Bissell   Taraji P. Henson          Sam Rockwell
# 3                    Claire Denis   Robert Pattinson      Juliette Binoche
# 4                     Brie Larson        Brie Larson     Samuel L. Jackson
# ..                            ...                ...                   ...
# 188        Nick Bruno, Troy Quane         Will Smith           Tom Holland
# 189                  Greta Gerwig      Saoirse Ronan           Emma Watson
# 190                    Sam Mendes      George MacKay  Dean-Charles Chapman
# 191         Destin Daniel Cretton  Michael B. Jordan            Jamie Foxx
# 192               Chinonye Chukwu      Alfre Woodard        Wendell Pierce
#
#        actor_3_name genres          movie_title  \
# 0       Mark Strong  Drama              shazam!
# 1      John Lithgow  Drama         pet sematary
# 2           unknown  Drama  the best of enemies
# 3    André Benjamin  Drama            high life
# 4       Joan Cusack  Drama        unicorn store
# ..              ...    ...                  ...
# 188   Rashida Jones  Drama    spies in disguise
# 189   Florence Pugh  Drama         little women
# 190     Mark Strong  Drama                 1917
# 191     Brie Larson  Drama           just mercy
# 192     Aldis Hodge  Drama             clemency
#
#                                                   comb
# 0    Zachary Levi Asher Angel Mark Strong David F. ...
# 1    Jason Clarke Amy Seimetz John Lithgow Kevin Ko...
# 2    Taraji P. Henson Sam Rockwell unknown Robin Bi...
# 3    Robert Pattinson Juliette Binoche André Benjam...
# 4    Brie Larson Samuel L. Jackson Joan Cusack Brie...
# ..                                                 ...
# 188  Will Smith Tom Holland Rashida Jones Nick Brun...
# 189  Saoirse Ronan Emma Watson Florence Pugh Greta ...
# 190  George MacKay Dean-Charles Chapman Mark Strong...
# 191  Michael B. Jordan Jamie Foxx Brie Larson Desti...
# 192  Alfre Woodard Wendell Pierce Aldis Hodge Chino...
#
# [193 rows x 7 columns]

# %% [markdown]
# # Extracting features of 2020 movies from Wikipedia

# %%
import pandas as pd
import numpy as np
import requests
import bs4 as bs
import urllib.request

# %%
link = "https://en.wikipedia.org/wiki/List_of_American_films_of_2020"

# %%
source = urllib.request.urlopen(link).read()
soup = bs.BeautifulSoup(source,'lxml')

# %%
tables = soup.find_all('table',class_='wikitable sortable')

# %%
df1 = pd.read_html(str(tables[0]))[0]
df2 = pd.read_html(str(tables[1]))[0]
df3 = pd.read_html(str(tables[2]))[0]
df4 = pd.read_html(str(tables[3]).replace("'1\"\'",'"1"'))[0] # avoided "ValueError: invalid literal for int() with base 10: '1"'

# %%
df = df1.append(df2.append(df3.append(df4,ignore_index=True),ignore_index=True),ignore_index=True)

# %%
df
# Out:
#       Opening  Opening.1                  Title  \
# 0     JANUARY          3             The Grudge
# 1     JANUARY         10             Underwater
# 2     JANUARY         10            Like a Boss
# 3     JANUARY         10          Three Christs
# 4     JANUARY         10      Inherit the Viper
# ..        ...        ...                    ...
# 270  DECEMBER         25       We Can Be Heroes
# 271  DECEMBER         25      News of the World
# 272  DECEMBER         25  One Night in Miami...
# 273  DECEMBER         25  Promising Young Woman
# 274  DECEMBER         30      Pieces of a Woman
#
#                                     Production company  \
# 0    Screen Gems / Stage 6 Films / Ghost House Pict...
# 1    20th Century Fox / TSG Entertainment / Chernin...
# 2                                   Paramount Pictures
# 3                                            IFC Films
# 4       Barry Films / Tycor International Film Company
# ..                                                 ...
# 270                     Netflix / Troublemaker Studios
# 271        Universal Pictures / Perfect World Pictures
# 272                                     Amazon Studios
# 273          Focus Features / FilmNation Entertainment
# 274                             Netflix / Bron Studios
#
#                                          Cast and crew  \
# 0    Nicolas Pesce (director/screenplay); Andrea Ri...
# 1    William Eubank (director); Brian Duffield, Ada...
# 2    Miguel Arteta (director); Sam Pitman, Adam Col...
# 3    Jon Avnet (director/screenplay); Eric Nazarian...
# 4    Anthony Jerjen (director); Andrew Crabtree (sc...
# ..                                                 ...
# 270  Robert Rodriguez (director/screenplay); Priyan...
# 271  Paul Greengrass (director/screenplay); Luke Da...
# 272  Regina King (director); Kemp Powers (screenpla...
# 273  Emerald Fennell (director/screenplay); Carey M...
# 274  Kornél Mundruczó (director); Kata Wéber (scree...
#
#     .mw-parser-output .tooltip-dotted{border-bottom:1px dotted;cursor:help}Ref.  \
# 0                                                  [2]
# 1                                                  [3]
# 2                                                  [4]
# 3                                                  NaN
# 4                                                  [5]
# ..                                                 ...
# 270                                                NaN
# 271                                                NaN
# 272                                                NaN
# 273                                                NaN
# 274                                                NaN
#
#       Ref.
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
# ..     ...
# 270  [241]
# 271  [242]
# 272  [243]
# 273  [244]
# 274  [245]
#
# [275 rows x 7 columns]

# %%
df_2020 = df[['Title','Cast and crew']]

# %%
df_2020
# Out:
#                      Title                                      Cast and crew
# 0               The Grudge  Nicolas Pesce (director/screenplay); Andrea Ri...
# 1               Underwater  William Eubank (director); Brian Duffield, Ada...
# 2              Like a Boss  Miguel Arteta (director); Sam Pitman, Adam Col...
# 3            Three Christs  Jon Avnet (director/screenplay); Eric Nazarian...
# 4        Inherit the Viper  Anthony Jerjen (director); Andrew Crabtree (sc...
# ..                     ...                                                ...
# 270       We Can Be Heroes  Robert Rodriguez (director/screenplay); Priyan...
# 271      News of the World  Paul Greengrass (director/screenplay); Luke Da...
# 272  One Night in Miami...  Regina King (director); Kemp Powers (screenpla...
# 273  Promising Young Woman  Emerald Fennell (director/screenplay); Carey M...
# 274      Pieces of a Woman  Kornél Mundruczó (director); Kata Wéber (scree...
#
# [275 rows x 2 columns]

# %%
# !pip install tmdbv3api
# Out:
# Requirement already satisfied: tmdbv3api in c:\users\acer\anaconda3\lib\site-packages (1.7.6)
# Requirement already satisfied: requests in c:\users\acer\anaconda3\lib\site-packages (from tmdbv3api) (2.25.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\acer\anaconda3\lib\site-packages (from requests->tmdbv3api) (2020.12.5)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\acer\anaconda3\lib\site-packages (from requests->tmdbv3api) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\acer\anaconda3\lib\site-packages (from requests->tmdbv3api) (1.26.4)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\acer\anaconda3\lib\site-packages (from requests->tmdbv3api) (4.0.0)

# %%
from tmdbv3api import TMDb
import json
import requests
tmdb = TMDb()
tmdb.api_key = '76d9e7057c5b2a49d4234f80154f044e'

# %%
from tmdbv3api import Movie
tmdb_movie = Movie()
def get_genre(x):
    genres = []
    result = tmdb_movie.search(x)
    if len(result) ==0:
        return np.NaN
    movie_id = result[0].id
    response = requests.get('https://api.themoviedb.org/3/movie/550?api_key=76d9e7057c5b2a49d4234f80154f044e'.format(movie_id,tmdb.api_key))
    data_json = response.json()
    if data_json['genres']:
        genre_str = " "
        for i in range(0,len(data_json['genres'])):
            genres.append(data_json['genres'][i]['name'])
        return genre_str.join(genres)
    else:
        np.NaN

# %%
df_2020['genres'] = df_2020['Title'].map(lambda x: get_genre(str(x)))
# Out:
# <ipython-input-13-fdc91464740e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2020['genres'] = df_2020['Title'].map(lambda x: get_genre(str(x)))

# %%
df_2020
# Out:
#                      Title                                      Cast and crew  \
# 0               The Grudge  Nicolas Pesce (director/screenplay); Andrea Ri...
# 1               Underwater  William Eubank (director); Brian Duffield, Ada...
# 2              Like a Boss  Miguel Arteta (director); Sam Pitman, Adam Col...
# 3            Three Christs  Jon Avnet (director/screenplay); Eric Nazarian...
# 4        Inherit the Viper  Anthony Jerjen (director); Andrew Crabtree (sc...
# ..                     ...                                                ...
# 270       We Can Be Heroes  Robert Rodriguez (director/screenplay); Priyan...
# 271      News of the World  Paul Greengrass (director/screenplay); Luke Da...
# 272  One Night in Miami...  Regina King (director); Kemp Powers (screenpla...
# 273  Promising Young Woman  Emerald Fennell (director/screenplay); Carey M...
# 274      Pieces of a Woman  Kornél Mundruczó (director); Kata Wéber (scree...
#
#     genres
# 0    Drama
# 1    Drama
# 2    Drama
# 3    Drama
# 4    Drama
# ..     ...
# 270  Drama
# 271  Drama
# 272  Drama
# 273  Drama
# 274  Drama
#
# [275 rows x 3 columns]

# %%
def get_director(x):
    if " (director)" in x:
        return x.split(" (director)")[0]
    elif " (directors)" in x:
        return x.split(" (directors)")[0]
    else:
        return x.split(" (director/screenplay)")[0]

# %%
df_2020['director_name'] = df_2020['Cast and crew'].map(lambda x: get_director(str(x)))
# Out:
# <ipython-input-16-bc52fe9b0c35>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2020['director_name'] = df_2020['Cast and crew'].map(lambda x: get_director(str(x)))

# %%
def get_actor1(x):
    return ((x.split("screenplay); ")[-1]).split(", ")[0])

# %%
df_2020['actor_1_name'] = df_2020['Cast and crew'].map(lambda x: get_actor1(str(x)))
# Out:
# <ipython-input-18-42c5f763f942>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2020['actor_1_name'] = df_2020['Cast and crew'].map(lambda x: get_actor1(str(x)))

# %%
def get_actor2(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 2:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[1])

# %%
df_2020['actor_2_name'] = df_2020['Cast and crew'].map(lambda x: get_actor2(str(x)))
# Out:
# <ipython-input-20-ca9c918a7840>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2020['actor_2_name'] = df_2020['Cast and crew'].map(lambda x: get_actor2(str(x)))

# %%
def get_actor3(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 3:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[2])

# %%
df_2020['actor_3_name'] = df_2020['Cast and crew'].map(lambda x: get_actor3(str(x)))

# %%
df_2020
# Out:
#                      Title                                      Cast and crew  \
# 0               The Grudge  Nicolas Pesce (director/screenplay); Andrea Ri...
# 1               Underwater  William Eubank (director); Brian Duffield, Ada...
# 2              Like a Boss  Miguel Arteta (director); Sam Pitman, Adam Col...
# 3            Three Christs  Jon Avnet (director/screenplay); Eric Nazarian...
# 4        Inherit the Viper  Anthony Jerjen (director); Andrew Crabtree (sc...
# ..                     ...                                                ...
# 270       We Can Be Heroes  Robert Rodriguez (director/screenplay); Priyan...
# 271      News of the World  Paul Greengrass (director/screenplay); Luke Da...
# 272  One Night in Miami...  Regina King (director); Kemp Powers (screenpla...
# 273  Promising Young Woman  Emerald Fennell (director/screenplay); Carey M...
# 274      Pieces of a Woman  Kornél Mundruczó (director); Kata Wéber (scree...
#
#     genres     director_name           actor_1_name       actor_2_name  \
# 0    Drama     Nicolas Pesce     Andrea Riseborough      Demián Bichir
# 1    Drama    William Eubank        Kristen Stewart     Vincent Cassel
# 2    Drama     Miguel Arteta        Tiffany Haddish         Rose Byrne
# 3    Drama         Jon Avnet           Richard Gere     Peter Dinklage
# 4    Drama    Anthony Jerjen          Josh Hartnett  Margarita Levieva
# ..     ...               ...                    ...                ...
# 270  Drama  Robert Rodriguez  Priyanka Chopra Jonas       Pedro Pascal
# 271  Drama   Paul Greengrass              Tom Hanks      Helena Zengel
# 272  Drama       Regina King      Kingsley Ben-Adir          Eli Goree
# 273  Drama   Emerald Fennell         Carey Mulligan         Bo Burnham
# 274  Drama  Kornél Mundruczó          Vanessa Kirby       Shia LaBeouf
#
#         actor_3_name
# 0           John Cho
# 1    Jessica Henwick
# 2        Salma Hayek
# 3     Walton Goggins
# 4     Chandler Riggs
# ..               ...
# 270    YaYa Gosselin
# 271              NaN
# 272      Aldis Hodge
# 273      Alison Brie
# 274     Molly Parker
#
# [275 rows x 7 columns]

# %%
df_2020 = df_2020.rename(columns={'Title':'movie_title'})

# %%
new_df20 = df_2020.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres','movie_title']]

# %%
new_df20
# Out:
#         director_name           actor_1_name       actor_2_name  \
# 0       Nicolas Pesce     Andrea Riseborough      Demián Bichir
# 1      William Eubank        Kristen Stewart     Vincent Cassel
# 2       Miguel Arteta        Tiffany Haddish         Rose Byrne
# 3           Jon Avnet           Richard Gere     Peter Dinklage
# 4      Anthony Jerjen          Josh Hartnett  Margarita Levieva
# ..                ...                    ...                ...
# 270  Robert Rodriguez  Priyanka Chopra Jonas       Pedro Pascal
# 271   Paul Greengrass              Tom Hanks      Helena Zengel
# 272       Regina King      Kingsley Ben-Adir          Eli Goree
# 273   Emerald Fennell         Carey Mulligan         Bo Burnham
# 274  Kornél Mundruczó          Vanessa Kirby       Shia LaBeouf
#
#         actor_3_name genres            movie_title
# 0           John Cho  Drama             The Grudge
# 1    Jessica Henwick  Drama             Underwater
# 2        Salma Hayek  Drama            Like a Boss
# 3     Walton Goggins  Drama          Three Christs
# 4     Chandler Riggs  Drama      Inherit the Viper
# ..               ...    ...                    ...
# 270    YaYa Gosselin  Drama       We Can Be Heroes
# 271              NaN  Drama      News of the World
# 272      Aldis Hodge  Drama  One Night in Miami...
# 273      Alison Brie  Drama  Promising Young Woman
# 274     Molly Parker  Drama      Pieces of a Woman
#
# [275 rows x 6 columns]

# %%
new_df20['comb'] = new_df20['actor_1_name'] + ' ' + new_df20['actor_2_name'] + ' '+ new_df20['actor_3_name'] + ' '+ new_df20['director_name'] +' ' + new_df20['genres']

# %%
new_df20 = new_df20.dropna(how='any')

# %%
new_df20['movie_title'] = new_df20['movie_title'].str.lower()
# Out:
# <ipython-input-29-83e83e91073b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df20['movie_title'] = new_df20['movie_title'].str.lower()

# %%
new_df20
# Out:
#         director_name           actor_1_name       actor_2_name  \
# 0       Nicolas Pesce     Andrea Riseborough      Demián Bichir
# 1      William Eubank        Kristen Stewart     Vincent Cassel
# 2       Miguel Arteta        Tiffany Haddish         Rose Byrne
# 3           Jon Avnet           Richard Gere     Peter Dinklage
# 4      Anthony Jerjen          Josh Hartnett  Margarita Levieva
# ..                ...                    ...                ...
# 269       Pete Docter             Jamie Foxx           Tina Fey
# 270  Robert Rodriguez  Priyanka Chopra Jonas       Pedro Pascal
# 272       Regina King      Kingsley Ben-Adir          Eli Goree
# 273   Emerald Fennell         Carey Mulligan         Bo Burnham
# 274  Kornél Mundruczó          Vanessa Kirby       Shia LaBeouf
#
#         actor_3_name genres            movie_title  \
# 0           John Cho  Drama             the grudge
# 1    Jessica Henwick  Drama             underwater
# 2        Salma Hayek  Drama            like a boss
# 3     Walton Goggins  Drama          three christs
# 4     Chandler Riggs  Drama      inherit the viper
# ..               ...    ...                    ...
# 269    Graham Norton  Drama                   soul
# 270    YaYa Gosselin  Drama       we can be heroes
# 272      Aldis Hodge  Drama  one night in miami...
# 273      Alison Brie  Drama  promising young woman
# 274     Molly Parker  Drama      pieces of a woman
#
#                                                   comb
# 0    Andrea Riseborough Demián Bichir John Cho Nico...
# 1    Kristen Stewart Vincent Cassel Jessica Henwick...
# 2    Tiffany Haddish Rose Byrne Salma Hayek Miguel ...
# 3    Richard Gere Peter Dinklage Walton Goggins Jon...
# 4    Josh Hartnett Margarita Levieva Chandler Riggs...
# ..                                                 ...
# 269  Jamie Foxx Tina Fey Graham Norton Pete Docter ...
# 270  Priyanka Chopra Jonas Pedro Pascal YaYa Gossel...
# 272  Kingsley Ben-Adir Eli Goree Aldis Hodge Regina...
# 273  Carey Mulligan Bo Burnham Alison Brie Emerald ...
# 274  Vanessa Kirby Shia LaBeouf Molly Parker Kornél...
#
# [246 rows x 7 columns]

# %% [markdown]
# # Extracting features of 2021 movies from wikipedia

# %%
link = "https://en.wikipedia.org/wiki/List_of_American_films_of_2021"
df1 = pd.read_html(link, header=0)[2]
df2 = pd.read_html(link, header=0)[3]
df3 = pd.read_html(link, header=0)[4]
df4 = pd.read_html(link, header=0)[5]

# %%
df = df1.append(df2.append(df3.append(df4,ignore_index=True),ignore_index=True),ignore_index=True)

# %%
! pip install tmdbv3api
# Out:
# Requirement already satisfied: tmdbv3api in c:\users\acer\anaconda3\lib\site-packages (1.7.6)
# Requirement already satisfied: requests in c:\users\acer\anaconda3\lib\site-packages (from tmdbv3api) (2.25.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\acer\anaconda3\lib\site-packages (from requests->tmdbv3api) (2020.12.5)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\acer\anaconda3\lib\site-packages (from requests->tmdbv3api) (1.26.4)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\acer\anaconda3\lib\site-packages (from requests->tmdbv3api) (2.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\acer\anaconda3\lib\site-packages (from requests->tmdbv3api) (4.0.0)

# %%
from tmdbv3api import TMDb
import json
import requests
tmdb = TMDb()
tmdb.api_key = '76d9e7057c5b2a49d4234f80154f044e'

# %%
df
# Out:
#       Opening  Opening.1                   Title  \
# 0     JANUARY        1.0     Shadow in the Cloud
# 1     JANUARY       13.0         The White Tiger
# 2     JANUARY       14.0             Locked Down
# 3     JANUARY       15.0                 The Dig
# 4     JANUARY       15.0        Outside the Wire
# ..        ...        ...                     ...
# 353  DECEMBER       25.0  The Tragedy of Macbeth
# 354  DECEMBER       25.0    A Journal for Jordan
# 355  DECEMBER       25.0       American Underdog
# 356  DECEMBER       26.0                 Memoria
# 357  DECEMBER        NaN                     NaN
#
#                                     Production company  \
# 0                               Vertical Entertainment
# 1                                              Netflix
# 2                      HBO Max / Warner Bros. Pictures
# 3                          Netflix / Clerkenwell Films
# 4                                              Netflix
# ..                                                 ...
# 353                        Apple TV+ / A24 / IAC Films
# 354  Columbia Pictures / Escape Artists / Bron Studios
# 355                                          Lionsgate
# 356                                               Neon
# 357                                                NaN
#
#                                          Cast and crew  \
# 0    Roseanne Liang (director/screenplay); Max Land...
# 1    Ramin Bahrani (director/screenplay); Adarsh Go...
# 2    Doug Liman (director); Steven Knight (screenpl...
# 3    Simon Stone (director); Moira Buffini (screenp...
# 4    Mikael Håfström (director); Rob Yescombe, Rowa...
# ..                                                 ...
# 353  Joel Coen (director/screenplay); Denzel Washin...
# 354  Denzel Washington (director); Virgil Williams ...
# 355  Erwin brothers (directors); Jon Erwin, David A...
# 356  Apichatpong Weerasethakul (director/acreenplay...
# 357                                                NaN
#
#     .mw-parser-output .tooltip-dotted{border-bottom:1px dotted;cursor:help}Ref.  \
# 0                                                  [2]
# 1                                                  NaN
# 2                                                  [3]
# 3                                                  [4]
# 4                                                  [5]
# ..                                                 ...
# 353                                                NaN
# 354                                                NaN
# 355                                                NaN
# 356                                                NaN
# 357                                                NaN
#
#       Ref.
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
# ..     ...
# 353  [271]
# 354  [272]
# 355  [273]
# 356  [274]
# 357    NaN
#
# [358 rows x 7 columns]

# %%
from tmdbv3api import Movie
tmdb_movie = Movie()
def get_genre(x):
    genres = []
    result = tmdb_movie.search(x)
    if len(result) ==0:
        return np.NaN
    movie_id = result[0].id
    response = requests.get('https://api.themoviedb.org/3/movie/550?api_key=76d9e7057c5b2a49d4234f80154f044e'.format(movie_id,tmdb.api_key))
    data_json = response.json()
    if data_json['genres']:
        genre_str = " "
        for i in range(0,len(data_json['genres'])):
            genres.append(data_json['genres'][i]['name'])
        return genre_str.join(genres)
    else:
        np.NaN

# %%
df['genres'] = df['Title'].map(lambda x: get_genre(str(x)))

# %%
df_2021 = df[['Title','Cast and crew','genres']]

# %%
df_2021
# Out:
#                    Title                                      Cast and crew  \
# 0                Shazam!  David F. Sandberg (director); Henry Gayden (sc...
# 1           Pet Sematary  Kevin Kolsch, Dennis Widmyer (directors); Jeff...
# 2    The Best of Enemies  Robin Bissell (director/screenplay); Taraji P....
# 3              High Life  Claire Denis (director/screenplay); Jean-Pol F...
# 4          Unicorn Store  Brie Larson (director); Samantha McIntyre (scr...
# ..                   ...                                                ...
# 188    Spies in Disguise  Nick Bruno, Troy Quane (directors); Brad Copel...
# 189         Little Women  Greta Gerwig (director/screenplay); Saoirse Ro...
# 190                 1917  Sam Mendes (director/screenplay); Krysty Wilso...
# 191           Just Mercy  Destin Daniel Cretton (director/screenplay), A...
# 192             Clemency  Chinonye Chukwu (director/screenplay); Alfre W...
#
#     genres
# 0    Drama
# 1    Drama
# 2    Drama
# 3    Drama
# 4    Drama
# ..     ...
# 188  Drama
# 189  Drama
# 190  Drama
# 191  Drama
# 192  Drama
#
# [193 rows x 3 columns]

# %%
def get_director(x):
    if " (director)" in x:
        return x.split(" (director)")[0]
    elif " (directors)" in x:
        return x.split(" (directors)")[0]
    else:
        return x.split(" (director/screenplay)")[0]

# %%
df_2021['director_name'] = df_2021['Cast and crew'].map(lambda x: get_director(str(x)))
# Out:
# <ipython-input-175-059d9cfe3ca6>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2021['director_name'] = df_2021['Cast and crew'].map(lambda x: get_director(str(x)))

# %%
def get_actor1(x):
    return ((x.split("screenplay); ")[-1]).split(", ")[0])

# %%
df_2021['actor_1_name'] = df_2021['Cast and crew'].map(lambda x: get_actor1(str(x)))
# Out:
# <ipython-input-177-fbf9a4980306>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2021['actor_1_name'] = df_2021['Cast and crew'].map(lambda x: get_actor1(str(x)))

# %%
def get_actor2(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 2:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[1])

# %%
df_2021['actor_2_name'] = df_2021['Cast and crew'].map(lambda x: get_actor2(str(x)))
# Out:
# <ipython-input-179-597eaf6de001>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2021['actor_2_name'] = df_2021['Cast and crew'].map(lambda x: get_actor2(str(x)))

# %%
def get_actor3(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 3:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[2])

# %%
df_2021['actor_3_name'] = df_2021['Cast and crew'].map(lambda x: get_actor3(str(x)))
# Out:
# <ipython-input-181-e73c3a751ade>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2021['actor_3_name'] = df_2021['Cast and crew'].map(lambda x: get_actor3(str(x)))

# %%
df_2021
# Out:
#                    Title                                      Cast and crew  \
# 0                Shazam!  David F. Sandberg (director); Henry Gayden (sc...
# 1           Pet Sematary  Kevin Kolsch, Dennis Widmyer (directors); Jeff...
# 2    The Best of Enemies  Robin Bissell (director/screenplay); Taraji P....
# 3              High Life  Claire Denis (director/screenplay); Jean-Pol F...
# 4          Unicorn Store  Brie Larson (director); Samantha McIntyre (scr...
# ..                   ...                                                ...
# 188    Spies in Disguise  Nick Bruno, Troy Quane (directors); Brad Copel...
# 189         Little Women  Greta Gerwig (director/screenplay); Saoirse Ro...
# 190                 1917  Sam Mendes (director/screenplay); Krysty Wilso...
# 191           Just Mercy  Destin Daniel Cretton (director/screenplay), A...
# 192             Clemency  Chinonye Chukwu (director/screenplay); Alfre W...
#
#     genres                 director_name       actor_1_name  \
# 0    Drama             David F. Sandberg       Zachary Levi
# 1    Drama  Kevin Kolsch, Dennis Widmyer       Jason Clarke
# 2    Drama                 Robin Bissell   Taraji P. Henson
# 3    Drama                  Claire Denis   Robert Pattinson
# 4    Drama                   Brie Larson        Brie Larson
# ..     ...                           ...                ...
# 188  Drama        Nick Bruno, Troy Quane         Will Smith
# 189  Drama                  Greta Gerwig      Saoirse Ronan
# 190  Drama                    Sam Mendes      George MacKay
# 191  Drama         Destin Daniel Cretton  Michael B. Jordan
# 192  Drama               Chinonye Chukwu      Alfre Woodard
#
#              actor_2_name    actor_3_name
# 0             Asher Angel     Mark Strong
# 1             Amy Seimetz    John Lithgow
# 2            Sam Rockwell             NaN
# 3        Juliette Binoche  André Benjamin
# 4       Samuel L. Jackson     Joan Cusack
# ..                    ...             ...
# 188           Tom Holland   Rashida Jones
# 189           Emma Watson   Florence Pugh
# 190  Dean-Charles Chapman     Mark Strong
# 191            Jamie Foxx     Brie Larson
# 192        Wendell Pierce     Aldis Hodge
#
# [193 rows x 7 columns]

# %%
df_2021 = df_2021.rename(columns={'Title':'movie_title'})

# %%
new_df21 = df_2021.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres','movie_title']]

# %%
new_df21
# Out:
#                     director_name       actor_1_name          actor_2_name  \
# 0               David F. Sandberg       Zachary Levi           Asher Angel
# 1    Kevin Kolsch, Dennis Widmyer       Jason Clarke           Amy Seimetz
# 2                   Robin Bissell   Taraji P. Henson          Sam Rockwell
# 3                    Claire Denis   Robert Pattinson      Juliette Binoche
# 4                     Brie Larson        Brie Larson     Samuel L. Jackson
# ..                            ...                ...                   ...
# 188        Nick Bruno, Troy Quane         Will Smith           Tom Holland
# 189                  Greta Gerwig      Saoirse Ronan           Emma Watson
# 190                    Sam Mendes      George MacKay  Dean-Charles Chapman
# 191         Destin Daniel Cretton  Michael B. Jordan            Jamie Foxx
# 192               Chinonye Chukwu      Alfre Woodard        Wendell Pierce
#
#        actor_3_name genres          movie_title
# 0       Mark Strong  Drama              Shazam!
# 1      John Lithgow  Drama         Pet Sematary
# 2               NaN  Drama  The Best of Enemies
# 3    André Benjamin  Drama            High Life
# 4       Joan Cusack  Drama        Unicorn Store
# ..              ...    ...                  ...
# 188   Rashida Jones  Drama    Spies in Disguise
# 189   Florence Pugh  Drama         Little Women
# 190     Mark Strong  Drama                 1917
# 191     Brie Larson  Drama           Just Mercy
# 192     Aldis Hodge  Drama             Clemency
#
# [193 rows x 6 columns]

# %%
new_df21['actor_2_name'] = new_df21['actor_2_name'].replace(np.nan, 'unknown')
new_df21['actor_3_name'] = new_df21['actor_3_name'].replace(np.nan, 'unknown')

# %%
new_df21['movie_title'] = new_df21['movie_title'].str.lower()

# %%
new_df21['comb'] = new_df21['actor_1_name'] + ' ' + new_df21['actor_2_name'] + ' ' + new_df21['actor_3_name'] + ' ' + new_df21['director_name'] + ' ' + new_df21['genres'] + ' ' + new_df21['movie_title']

# %%
new_df21
# Out:
#                     director_name       actor_1_name          actor_2_name  \
# 0               David F. Sandberg       Zachary Levi           Asher Angel
# 1    Kevin Kolsch, Dennis Widmyer       Jason Clarke           Amy Seimetz
# 2                   Robin Bissell   Taraji P. Henson          Sam Rockwell
# 3                    Claire Denis   Robert Pattinson      Juliette Binoche
# 4                     Brie Larson        Brie Larson     Samuel L. Jackson
# ..                            ...                ...                   ...
# 188        Nick Bruno, Troy Quane         Will Smith           Tom Holland
# 189                  Greta Gerwig      Saoirse Ronan           Emma Watson
# 190                    Sam Mendes      George MacKay  Dean-Charles Chapman
# 191         Destin Daniel Cretton  Michael B. Jordan            Jamie Foxx
# 192               Chinonye Chukwu      Alfre Woodard        Wendell Pierce
#
#        actor_3_name genres          movie_title  \
# 0       Mark Strong  Drama              shazam!
# 1      John Lithgow  Drama         pet sematary
# 2           unknown  Drama  the best of enemies
# 3    André Benjamin  Drama            high life
# 4       Joan Cusack  Drama        unicorn store
# ..              ...    ...                  ...
# 188   Rashida Jones  Drama    spies in disguise
# 189   Florence Pugh  Drama         little women
# 190     Mark Strong  Drama                 1917
# 191     Brie Larson  Drama           just mercy
# 192     Aldis Hodge  Drama             clemency
#
#                                                   comb
# 0    Zachary Levi Asher Angel Mark Strong David F. ...
# 1    Jason Clarke Amy Seimetz John Lithgow Kevin Ko...
# 2    Taraji P. Henson Sam Rockwell unknown Robin Bi...
# 3    Robert Pattinson Juliette Binoche André Benjam...
# 4    Brie Larson Samuel L. Jackson Joan Cusack Brie...
# ..                                                 ...
# 188  Will Smith Tom Holland Rashida Jones Nick Brun...
# 189  Saoirse Ronan Emma Watson Florence Pugh Greta ...
# 190  George MacKay Dean-Charles Chapman Mark Strong...
# 191  Michael B. Jordan Jamie Foxx Brie Larson Desti...
# 192  Alfre Woodard Wendell Pierce Aldis Hodge Chino...
#
# [193 rows x 7 columns]

# %% [markdown]
# # Extracting features of 2022 movies from wikipedia

# %%
link = "https://en.wikipedia.org/wiki/List_of_American_films_of_2022"
df1 = pd.read_html(link, header=0)[2]
df2 = pd.read_html(link, header=0)[3]
df3 = pd.read_html(link, header=0)[4]
df4 = pd.read_html(link, header=0)[5]

# %%
df = df1.append(df2.append(df3.append(df4,ignore_index=True),ignore_index=True),ignore_index=True)

# %%
df
# Out:
#      Rank                                         Title   Distributor  \
# 0     1.0                                   The Batman*  Warner Bros.
# 1     2.0  Doctor Strange in the Multiverse of Madness*        Disney
# 2     3.0                         Sonic the Hedgehog 2*     Paramount
# 3     4.0                                     Uncharted          Sony
# 4     5.0                                The Lost City*     Paramount
# ..    ...                                           ...           ...
# 175   NaN          Are You There God? It's Me, Margaret           NaN
# 176   NaN                                       Distant           NaN
# 177   NaN                           Don't Worry Darling           NaN
# 178   NaN                                          Bros           NaN
# 179   NaN                                           NaN           NaN
#
#     Domestic Gross    Opening  Opening.1  \
# 0     $369,309,462        NaN        NaN
# 1     $351,992,340        NaN        NaN
# 2     $181,950,102        NaN        NaN
# 3     $147,726,420        NaN        NaN
# 4      $99,674,006        NaN        NaN
# ..             ...        ...        ...
# 175            NaN  SEPTEMBER       16.0
# 176            NaN  SEPTEMBER       16.0
# 177            NaN  SEPTEMBER       23.0
# 178            NaN  SEPTEMBER       30.0
# 179            NaN  SEPTEMBER        NaN
#
#                                     Production company  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 175                           Lionsgate / Gracie Films
# 176  Universal Pictures / DreamWorks Pictures / Amb...
# 177            Warner Bros. Pictures / New Line Cinema
# 178            Universal Pictures / Apatow Productions
# 179                                                NaN
#
#                                          Cast and crew  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 175  Kelly Fremon Craig (director/screenplay); Rach...
# 176  Josh Gordon & Will Speck (directors); Spenser ...
# 177  Olivia Wilde (director); Katie Silberman (scre...
# 178  Nicholas Stoller (director/screenplay); Billy ...
# 179                                                NaN
#
#     .mw-parser-output .tooltip-dotted{border-bottom:1px dotted;cursor:help}Ref.  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 175                                                NaN
# 176                                                NaN
# 177                                                NaN
# 178                                                NaN
# 179                                                NaN
#
#       Ref.
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
# ..     ...
# 175  [144]
# 176  [145]
# 177  [146]
# 178  [147]
# 179    NaN
#
# [180 rows x 10 columns]

# %%
! pip install tmdbv3api
# Out:
# Requirement already satisfied: tmdbv3api in c:\users\acer\anaconda3\lib\site-packages (1.7.6)
# Requirement already satisfied: requests in c:\users\acer\anaconda3\lib\site-packages (from tmdbv3api) (2.25.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\acer\anaconda3\lib\site-packages (from requests->tmdbv3api) (1.26.4)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\acer\anaconda3\lib\site-packages (from requests->tmdbv3api) (4.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\acer\anaconda3\lib\site-packages (from requests->tmdbv3api) (2020.12.5)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\acer\anaconda3\lib\site-packages (from requests->tmdbv3api) (2.10)

# %%
from tmdbv3api import TMDb
import json
import requests
tmdb = TMDb()
tmdb.api_key = '76d9e7057c5b2a49d4234f80154f044e'

# %%
from tmdbv3api import Movie
tmdb_movie = Movie()
def get_genre(x):
    genres = []
    result = tmdb_movie.search(x)
    movie_id = result[0].id
    response = requests.get('https://api.themoviedb.org/3/movie/550?api_key=76d9e7057c5b2a49d4234f80154f044e'.format(movie_id,tmdb.api_key))
    data_json = response.json()
    if data_json['genres']:
        genre_str = " "
        for i in range(0,len(data_json['genres'])):
            genres.append(data_json['genres'][i]['name'])
        return genre_str.join(genres)
    else:
        np.NaN

# %%
df['genres'] = df['Title'].map(lambda x: get_genre(str(x)))

# %%
df_2022 = df[['Title','Cast and crew','genres']]

# %%
df_2022
# Out:
#                                             Title  \
# 0                                     The Batman*
# 1    Doctor Strange in the Multiverse of Madness*
# 2                           Sonic the Hedgehog 2*
# 3                                       Uncharted
# 4                                  The Lost City*
# ..                                            ...
# 175          Are You There God? It's Me, Margaret
# 176                                       Distant
# 177                           Don't Worry Darling
# 178                                          Bros
# 179                                           NaN
#
#                                          Cast and crew genres
# 0                                                  NaN  Drama
# 1                                                  NaN  Drama
# 2                                                  NaN  Drama
# 3                                                  NaN  Drama
# 4                                                  NaN  Drama
# ..                                                 ...    ...
# 175  Kelly Fremon Craig (director/screenplay); Rach...  Drama
# 176  Josh Gordon & Will Speck (directors); Spenser ...  Drama
# 177  Olivia Wilde (director); Katie Silberman (scre...  Drama
# 178  Nicholas Stoller (director/screenplay); Billy ...  Drama
# 179                                                NaN  Drama
#
# [180 rows x 3 columns]

# %%
def get_director(x):
    if " (director)" in x:
        return x.split(" (director)")[0]
    elif " (directors)" in x:
        return x.split(" (directors)")[0]
    else:
        return x.split(" (director/screenplay)")[0]

# %%
df_2022['director_name'] = df_2022['Cast and crew'].map(lambda x: get_director(str(x)))
# Out:
# <ipython-input-200-bde37e357dd2>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2022['director_name'] = df_2022['Cast and crew'].map(lambda x: get_director(str(x)))

# %%
def get_actor1(x):
    return ((x.split("screenplay); ")[-1]).split(", ")[0])

# %%
df_2022['actor_1_name'] = df_2022['Cast and crew'].map(lambda x: get_actor1(str(x)))
# Out:
# <ipython-input-202-e67b31464e65>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2022['actor_1_name'] = df_2022['Cast and crew'].map(lambda x: get_actor1(str(x)))

# %%
def get_actor2(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 2:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[1])

# %%
df_2022['actor_2_name'] = df_2022['Cast and crew'].map(lambda x: get_actor2(str(x)))
# Out:
# <ipython-input-204-d3d5c35d26fc>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2022['actor_2_name'] = df_2022['Cast and crew'].map(lambda x: get_actor2(str(x)))

# %%
def get_actor3(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 3:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[2])

# %%
df_2022['actor_3_name'] = df_2022['Cast and crew'].map(lambda x: get_actor3(str(x)))
# Out:
# <ipython-input-206-0c65546c30a0>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2022['actor_3_name'] = df_2022['Cast and crew'].map(lambda x: get_actor3(str(x)))

# %%
df_2022
# Out:
#                                             Title  \
# 0                                     The Batman*
# 1    Doctor Strange in the Multiverse of Madness*
# 2                           Sonic the Hedgehog 2*
# 3                                       Uncharted
# 4                                  The Lost City*
# ..                                            ...
# 175          Are You There God? It's Me, Margaret
# 176                                       Distant
# 177                           Don't Worry Darling
# 178                                          Bros
# 179                                           NaN
#
#                                          Cast and crew genres  \
# 0                                                  NaN  Drama
# 1                                                  NaN  Drama
# 2                                                  NaN  Drama
# 3                                                  NaN  Drama
# 4                                                  NaN  Drama
# ..                                                 ...    ...
# 175  Kelly Fremon Craig (director/screenplay); Rach...  Drama
# 176  Josh Gordon & Will Speck (directors); Spenser ...  Drama
# 177  Olivia Wilde (director); Katie Silberman (scre...  Drama
# 178  Nicholas Stoller (director/screenplay); Billy ...  Drama
# 179                                                NaN  Drama
#
#                 director_name    actor_1_name        actor_2_name  \
# 0                         nan             nan                 NaN
# 1                         nan             nan                 NaN
# 2                         nan             nan                 NaN
# 3                         nan             nan                 NaN
# 4                         nan             nan                 NaN
# ..                        ...             ...                 ...
# 175        Kelly Fremon Craig  Rachel McAdams  Abby Ryder Fortson
# 176  Josh Gordon & Will Speck   Anthony Ramos         Naomi Scott
# 177              Olivia Wilde   Florence Pugh        Harry Styles
# 178          Nicholas Stoller   Billy Eichner     Luke Macfarlane
# 179                       nan             nan                 NaN
#
#        actor_3_name
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
# ..              ...
# 175    Benny Safdie
# 176  Zachary Quinto
# 177    Olivia Wilde
# 178      Ts Madison
# 179             NaN
#
# [180 rows x 7 columns]

# %%
df_2022 = df_2022.rename(columns={'Title':'movie_title'})

# %%
new_df22 = df_2022.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres','movie_title']]

# %%
new_df22
# Out:
#                 director_name    actor_1_name        actor_2_name  \
# 0                         nan             nan                 NaN
# 1                         nan             nan                 NaN
# 2                         nan             nan                 NaN
# 3                         nan             nan                 NaN
# 4                         nan             nan                 NaN
# ..                        ...             ...                 ...
# 175        Kelly Fremon Craig  Rachel McAdams  Abby Ryder Fortson
# 176  Josh Gordon & Will Speck   Anthony Ramos         Naomi Scott
# 177              Olivia Wilde   Florence Pugh        Harry Styles
# 178          Nicholas Stoller   Billy Eichner     Luke Macfarlane
# 179                       nan             nan                 NaN
#
#        actor_3_name genres                                   movie_title
# 0               NaN  Drama                                   The Batman*
# 1               NaN  Drama  Doctor Strange in the Multiverse of Madness*
# 2               NaN  Drama                         Sonic the Hedgehog 2*
# 3               NaN  Drama                                     Uncharted
# 4               NaN  Drama                                The Lost City*
# ..              ...    ...                                           ...
# 175    Benny Safdie  Drama          Are You There God? It's Me, Margaret
# 176  Zachary Quinto  Drama                                       Distant
# 177    Olivia Wilde  Drama                           Don't Worry Darling
# 178      Ts Madison  Drama                                          Bros
# 179             NaN  Drama                                           NaN
#
# [180 rows x 6 columns]

# %%
new_df22['actor_2_name'] = new_df22['actor_2_name'].replace(np.nan, 'unknown')
new_df22['actor_3_name'] = new_df22['actor_3_name'].replace(np.nan, 'unknown')

# %%
new_df22['movie_title'] = new_df22['movie_title'].str.lower()

# %%
new_df22['comb'] = new_df22['actor_1_name'] + ' ' + new_df22['actor_2_name'] + ' ' + new_df22['actor_3_name'] + ' ' + new_df22['director_name'] + ' ' + new_df22['genres'] + ' ' + new_df22['movie_title']

# %%
new_df22
# Out:
#                 director_name    actor_1_name        actor_2_name  \
# 0                         nan             nan             unknown
# 1                         nan             nan             unknown
# 2                         nan             nan             unknown
# 3                         nan             nan             unknown
# 4                         nan             nan             unknown
# ..                        ...             ...                 ...
# 175        Kelly Fremon Craig  Rachel McAdams  Abby Ryder Fortson
# 176  Josh Gordon & Will Speck   Anthony Ramos         Naomi Scott
# 177              Olivia Wilde   Florence Pugh        Harry Styles
# 178          Nicholas Stoller   Billy Eichner     Luke Macfarlane
# 179                       nan             nan             unknown
#
#        actor_3_name genres                                   movie_title  \
# 0           unknown  Drama                                   the batman*
# 1           unknown  Drama  doctor strange in the multiverse of madness*
# 2           unknown  Drama                         sonic the hedgehog 2*
# 3           unknown  Drama                                     uncharted
# 4           unknown  Drama                                the lost city*
# ..              ...    ...                                           ...
# 175    Benny Safdie  Drama          are you there god? it's me, margaret
# 176  Zachary Quinto  Drama                                       distant
# 177    Olivia Wilde  Drama                           don't worry darling
# 178      Ts Madison  Drama                                          bros
# 179         unknown  Drama                                           NaN
#
#                                                   comb
# 0            nan unknown unknown nan Drama the batman*
# 1    nan unknown unknown nan Drama doctor strange i...
# 2    nan unknown unknown nan Drama sonic the hedgeh...
# 3              nan unknown unknown nan Drama uncharted
# 4         nan unknown unknown nan Drama the lost city*
# ..                                                 ...
# 175  Rachel McAdams Abby Ryder Fortson Benny Safdie...
# 176  Anthony Ramos Naomi Scott Zachary Quinto Josh ...
# 177  Florence Pugh Harry Styles Olivia Wilde Olivia...
# 178  Billy Eichner Luke Macfarlane Ts Madison Nicho...
# 179                                                NaN
#
# [180 rows x 7 columns]

# %% [markdown]
# # Combining data till 2017 and 2018-2022

# %%
my_df = new_df18.append(new_df19.append(new_df20.append(new_df21.append(new_df22,ignore_index=True),ignore_index=True),ignore_index=True),ignore_index=True)

# %%
my_df
# Out:
#                  director_name    actor_1_name            actor_2_name  \
# 0                 Adam Robitel       Lin Shaye           Angus Sampson
# 1             Lauren Wolkstein   Alex Pettyfer  James Freedson-Jackson
# 2                   Simon West  Dominic Cooper          Austin Stowell
# 3             Warwick Thornton     Bryan Brown               Sam Neill
# 4           Jaume Collet-Serra     Liam Neeson            Vera Farmiga
# ...                        ...             ...                     ...
# 1079        Kelly Fremon Craig  Rachel McAdams      Abby Ryder Fortson
# 1080  Josh Gordon & Will Speck   Anthony Ramos             Naomi Scott
# 1081              Olivia Wilde   Florence Pugh            Harry Styles
# 1082          Nicholas Stoller   Billy Eichner         Luke Macfarlane
# 1083                       nan             nan                 unknown
#
#         actor_3_name genres                           movie_title  \
# 0     Leigh Whannell  Drama               insidious: the last key
# 1      Emily Althaus  Drama                      the strange ones
# 2         Gemma Chan  Drama                              stratton
# 3            unknown  Drama                         sweet country
# 4     Patrick Wilson  Drama                          the commuter
# ...              ...    ...                                   ...
# 1079    Benny Safdie  Drama  are you there god? it's me, margaret
# 1080  Zachary Quinto  Drama                               distant
# 1081    Olivia Wilde  Drama                   don't worry darling
# 1082      Ts Madison  Drama                                  bros
# 1083         unknown  Drama                                   NaN
#
#                                                    comb
# 0     Lin Shaye Angus Sampson Leigh Whannell Adam Ro...
# 1     Alex Pettyfer James Freedson-Jackson Emily Alt...
# 2     Dominic Cooper Austin Stowell Gemma Chan Simon...
# 3     Bryan Brown Sam Neill unknown Warwick Thornton...
# 4     Liam Neeson Vera Farmiga Patrick Wilson Jaume ...
# ...                                                 ...
# 1079  Rachel McAdams Abby Ryder Fortson Benny Safdie...
# 1080  Anthony Ramos Naomi Scott Zachary Quinto Josh ...
# 1081  Florence Pugh Harry Styles Olivia Wilde Olivia...
# 1082  Billy Eichner Luke Macfarlane Ts Madison Nicho...
# 1083                                                NaN
#
# [1084 rows x 7 columns]

# %%
old_df = pd.read_csv(r"C:\Users\acer\Downloads\The-Movie-Cinema-master\The-Movie-Cinema-master\datasets\movie.csv")

# %%
old_df
# Out:
#          director_name     actor_1_name    actor_2_name     actor_3_name  \
# 0        John Lasseter        Tom Hanks       Tim Allen      Don Rickles
# 1         Joe Johnston   Robin Williams   Jonathan Hyde    Kirsten Dunst
# 2        Howard Deutch   Walter Matthau     Jack Lemmon      Ann-Margret
# 3      Forest Whitaker  Whitney Houston  Angela Bassett   Loretta Devine
# 4        Charles Shyer     Steve Martin    Diane Keaton     Martin Short
# ...                ...              ...             ...              ...
# 36336         Ben Rock       Monty Bane     Lucy Butler    David Grammer
# 36337    Aaron Osborne       Lisa Boyle       Kena Land    Zaneta Polard
# 36338       John Irvin   Patrick Bergin     Uma Thurman  David Morrissey
# 36339         Lav Diaz     Angel Aquino     Perry Dizon    Hazel Orencio
# 36340   Mark L. Lester    Erika Eleniak    Adam Baldwin    Julie du Page
#
#                          genres                  movie_title  \
# 0       Animation Comedy Family                    toy story
# 1      Adventure Fantasy Family                      jumanji
# 2                Romance Comedy             grumpier old men
# 3          Comedy Drama Romance            waiting to exhale
# 4                        Comedy  father of the bride part ii
# ...                         ...                          ...
# 36336                    Horror          the burkittsville 7
# 36337                    Sci-Fi              caged heat 3000
# 36338      Drama Action Romance                   robin hood
# 36339                     Drama          century of birthing
# 36340     Action Drama Thriller                     betrayal
#
#                                                     comb
# 0      Tom Hanks Tim Allen Don Rickles John Lasseter ...
# 1      Robin Williams Jonathan Hyde Kirsten Dunst Joe...
# 2      Walter Matthau Jack Lemmon Ann-Margret Howard ...
# 3      Whitney Houston Angela Bassett Loretta Devine ...
# 4      Steve Martin Diane Keaton Martin Short Charles...
# ...                                                  ...
# 36336  Monty Bane Lucy Butler David Grammer Ben Rock ...
# 36337  Lisa Boyle Kena Land Zaneta Polard Aaron Osbor...
# 36338  Patrick Bergin Uma Thurman David Morrissey Joh...
# 36339  Angel Aquino Perry Dizon Hazel Orencio Lav Dia...
# 36340  Erika Eleniak Adam Baldwin Julie du Page Mark ...
#
# [36341 rows x 7 columns]

# %%
final_df = old_df.append(my_df,ignore_index=True)

# %%
final_df
# Out:
#                   director_name     actor_1_name        actor_2_name  \
# 0                 John Lasseter        Tom Hanks           Tim Allen
# 1                  Joe Johnston   Robin Williams       Jonathan Hyde
# 2                 Howard Deutch   Walter Matthau         Jack Lemmon
# 3               Forest Whitaker  Whitney Houston      Angela Bassett
# 4                 Charles Shyer     Steve Martin        Diane Keaton
# ...                         ...              ...                 ...
# 37420        Kelly Fremon Craig   Rachel McAdams  Abby Ryder Fortson
# 37421  Josh Gordon & Will Speck    Anthony Ramos         Naomi Scott
# 37422              Olivia Wilde    Florence Pugh        Harry Styles
# 37423          Nicholas Stoller    Billy Eichner     Luke Macfarlane
# 37424                       nan              nan             unknown
#
#          actor_3_name                    genres  \
# 0         Don Rickles   Animation Comedy Family
# 1       Kirsten Dunst  Adventure Fantasy Family
# 2         Ann-Margret            Romance Comedy
# 3      Loretta Devine      Comedy Drama Romance
# 4        Martin Short                    Comedy
# ...               ...                       ...
# 37420    Benny Safdie                     Drama
# 37421  Zachary Quinto                     Drama
# 37422    Olivia Wilde                     Drama
# 37423      Ts Madison                     Drama
# 37424         unknown                     Drama
#
#                                 movie_title  \
# 0                                 toy story
# 1                                   jumanji
# 2                          grumpier old men
# 3                         waiting to exhale
# 4               father of the bride part ii
# ...                                     ...
# 37420  are you there god? it's me, margaret
# 37421                               distant
# 37422                   don't worry darling
# 37423                                  bros
# 37424                                   NaN
#
#                                                     comb
# 0      Tom Hanks Tim Allen Don Rickles John Lasseter ...
# 1      Robin Williams Jonathan Hyde Kirsten Dunst Joe...
# 2      Walter Matthau Jack Lemmon Ann-Margret Howard ...
# 3      Whitney Houston Angela Bassett Loretta Devine ...
# 4      Steve Martin Diane Keaton Martin Short Charles...
# ...                                                  ...
# 37420  Rachel McAdams Abby Ryder Fortson Benny Safdie...
# 37421  Anthony Ramos Naomi Scott Zachary Quinto Josh ...
# 37422  Florence Pugh Harry Styles Olivia Wilde Olivia...
# 37423  Billy Eichner Luke Macfarlane Ts Madison Nicho...
# 37424                                                NaN
#
# [37425 rows x 7 columns]

# %%
final_df.isna().sum()
# Out:
# director_name    0
# actor_1_name     0
# actor_2_name     0
# actor_3_name     0
# genres           0
# movie_title      1
# comb             1
# dtype: int64

# %%
final_df = final_df.dropna(how='any')

# %%
final_df.to_csv('final_data.csv',index=False)
